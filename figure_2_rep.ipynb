# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Data
l_1 = [1.614, 1.502, 1.515, 1.513] #bvae (0.01)
l_2 = [1.615, 1.505, 1.502, 1.513] #bvae(0.1)
l_3 = [1.66, 1.514, 1.498, 1.509] #bvae(10)
l_4 = [1.817, 1.546, 1.5, 1.51] #bvae(100)
#cevae
ceave = [1.622, 1.528, 1.505, 1.510 ]
cvae = [1.773, 1.546, 1.522, 1.502]
bvae = [1.622, 1.528, 1.501, 1.510]
hvae = [1.622,1.528, 1.501,1.510 ]
vqvae = [1.558, 1.503, 1.509,1.497 ]
x = [np.log10(1000), np.log10(3000), np.log10(5000), np.log10(10000)]
# Plot
plt.plot(x, l_1, marker='o', label='bvae (0.01)')
plt.plot(x, l_2, marker='o', label='bvae (0.1)')
plt.plot(x, l_3, marker='o', label='bvae (10)')
plt.plot(x, l_4, marker='o', label='bvae (100)')
plt.plot(x, ceave, marker='o', label='cevae')
plt.plot(x, cvae, marker='o', label='cvae')
plt.plot(x, bvae, marker='o', label='bvae')
plt.plot(x, hvae, marker='o', label='hvae')

# Labels and legend
plt.xlabel('log(Nsamples)')
plt.ylabel('absolute ATE error')
plt.title('Absolute error of estimating ATE on samples')
plt.legend()
plt.grid(True)
plt.show()
